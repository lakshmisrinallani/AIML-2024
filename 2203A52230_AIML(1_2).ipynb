# %%
people = ['kiran', 'arun', 'vijay', 'varun']
age =[25, 30, 35, 40]
height =[145, 151, 165, 173]
weight=[45, 55, 65, 75]

# %%
import matplotlib.pyplot as plt
plt.scatter(people,age)

# %%
plt.scatter(age,height)

# %%
plt.scatter(people,weight)

# %%
plt.title("relation btw people and age")
plt.xlabel("people")
plt.ylabel("age")
plt.bar(people,age)
# Out:
# <BarContainer object of 4 artists>

# %%
plt.title("relation btw height and age")
plt.xlabel("height")
plt.ylabel("age")
plt.bar(height,age)
# Out:
# <BarContainer object of 4 artists>

# %%
plt.title("relation btw height and weight")
plt.xlabel("height")
plt.ylabel("weight")
plt.bar(height,weight)
# Out:
# <BarContainer object of 4 artists>

# %%
plt.hist(people)
plt.show()

# %%
plt.hist(age)
# Out:
# (array([1., 0., 0., 1., 0., 0., 1., 0., 0., 1.]),
#  array([25. , 26.5, 28. , 29.5, 31. , 32.5, 34. , 35.5, 37. , 38.5, 40. ]),
#  <BarContainer object of 10 artists>)
